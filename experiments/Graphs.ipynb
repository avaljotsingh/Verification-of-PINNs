# %%
import sys
import time
sys.path.append("../src")
from util import visualize_per_partition_bounds, visualize_per_partition_bounds_mult, visualize_per_partition_bounds_multss

# %%
model = "../trained_models/pinn-burgers-vis-1500.pt"
model = "../trained_models/pinn-burgers_pgd_train_1500.pt"
np = 150
visualize_per_partition_bounds(model, np)
# Out:
# tensor(59.2662)
# tensor(0.0315)
# tensor([[0.4391, 0.4221, 0.4053,  ..., 0.0722, 0.0729, 0.0736],
#         [0.4259, 0.4103, 0.3950,  ..., 0.0682, 0.0690, 0.0697],
#         [0.4117, 0.3978, 0.3840,  ..., 0.0648, 0.0656, 0.0664],
#         ...,
#         [0.5632, 0.5389, 0.5154,  ..., 0.0525, 0.0522, 0.0519],
#         [0.5618, 0.5373, 0.5137,  ..., 0.0570, 0.0567, 0.0565],
#         [0.5590, 0.5344, 0.5109,  ..., 0.0619, 0.0617, 0.0615]])

# %%
model = "../trained_models/pinn-burgers-vis-1500.pt"
np = 150
visualize_per_partition_bounds(model, np, (-1, -0.1))
# Out:
# tensor(1.7623)
# tensor(0.0117)
# tensor([[0.3261, 0.3109, 0.2963,  ..., 0.0157, 0.0159, 0.0161],
#         [0.3248, 0.3096, 0.2950,  ..., 0.0163, 0.0165, 0.0167],
#         [0.3233, 0.3080, 0.2934,  ..., 0.0169, 0.0171, 0.0173],
#         ...,
#         [1.2316, 1.1171, 1.0672,  ..., 0.5508, 0.5570, 0.5629],
#         [1.4949, 1.3747, 1.2542,  ..., 0.5428, 0.5481, 0.5533],
#         [1.7623, 1.6514, 1.5319,  ..., 0.5342, 0.5387, 0.5430]])

# %%
model = "../trained_models/pinn-burgers-vis-1500.pt"
np = 68
visualize_per_partition_bounds_mult(model, np, ((-1, -0.1), (0.1, 1)), ((0, 1),(0, 1)), num_parts1 = 150)

# %%
# model = "../trained_models/pinn-burgers-vis-1500.pt"
model = "../trained_models/pinn-burgers_pgd_train_1500.pt"
np = 14
visualize_per_partition_bounds(model, np, (-0.1, 0.1), (0,1), num_parts1=150)

# visualize_per_partition_bounds(model, np, (-0.1, 0.1), (0, 1), num_parts1 = 150)
# Out:
# tensor(61.0393)
# tensor(0.4425)
# tensor([[1.4693, 1.5526, 1.6393,  ..., 1.3475, 1.3525, 1.3563],
#         [1.1890, 1.2575, 1.3298,  ..., 1.5179, 1.5204, 1.5216],
#         [0.9569, 1.0103, 1.0669,  ..., 1.8315, 1.8311, 1.8290],
#         ...,
#         [0.4537, 0.4585, 0.4637,  ..., 1.9538, 1.9940, 2.0355],
#         [0.4748, 0.4798, 0.4852,  ..., 1.3532, 1.3771, 1.4024],
#         [0.5021, 0.5075, 0.5134,  ..., 0.9981, 1.0124, 1.0275]])

# %%
model1 = "../trained_models/pinn-burgers-vis-1500.pt"
model2 = "../trained_models/pinn-burgers_pgd_train_1500.pt"
np = 150

visualize_per_partition_bounds_multss([model1, model2], np, (-1,1), (0,1))
# visualize_per_partition_bounds(model, np)
# Out:
# tensor(102.1720)
# tensor(0.0201)
# tensor([[0.3892, 0.3721, 0.3558,  ..., 0.0235, 0.0237, 0.0239],
#         [0.3928, 0.3754, 0.3588,  ..., 0.0252, 0.0254, 0.0256],
#         [0.3955, 0.3779, 0.3610,  ..., 0.0268, 0.0270, 0.0272],
#         ...,
#         [0.5627, 0.5455, 0.5286,  ..., 0.0436, 0.0428, 0.0420],
#         [0.5518, 0.5345, 0.5177,  ..., 0.0460, 0.0453, 0.0445],
#         [0.5393, 0.5223, 0.5056,  ..., 0.0486, 0.0479, 0.0472]])
# tensor(59.3048)
# tensor(0.0316)
# tensor([[0.4430, 0.4257, 0.4088,  ..., 0.0726, 0.0733, 0.0741],
#         [0.4296, 0.4138, 0.3983,  ..., 0.0686, 0.0694, 0.0702],
#         [0.4152, 0.4012, 0.3872,  ..., 0.0652, 0.0659, 0.0668],
#         ...,
#         [0.5672, 0.5427, 0.5191,  ..., 0.0528, 0.0525, 0.0522],
#         [0.5658, 0.5411, 0.5173,  ..., 0.0573, 0.0571, 0.0569],
#         [0.5629, 0.5381, 0.5143,  ..., 0.0622, 0.0621, 0.0619]])

# %%
model = "../trained_models/pinn-burgers_certif_sampling_100.pt"
np = 150
visualize_per_partition_bounds(model, np)
# Out:
# tensor(0.5861)
# tensor(0.0367)
# tensor([[0.1273, 0.1278, 0.1283,  ..., 0.1021, 0.1015, 0.1008],
#         [0.1222, 0.1227, 0.1232,  ..., 0.0992, 0.0986, 0.0980],
#         [0.1171, 0.1176, 0.1181,  ..., 0.0962, 0.0956, 0.0949],
#         ...,
#         [0.1199, 0.1205, 0.1210,  ..., 0.1076, 0.1070, 0.1064],
#         [0.1259, 0.1264, 0.1270,  ..., 0.1112, 0.1106, 0.1100],
#         [0.1318, 0.1323, 0.1328,  ..., 0.1150, 0.1144, 0.1139]])
