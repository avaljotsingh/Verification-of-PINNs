# %%
import sys
import time
sys.path.append("../src")
from util import visualize_per_partition_bounds, visualize_per_partition_bounds_mult

# %%
model = "../trained_models/pinn-burgers-vis-1500.pt"
np = 150
visualize_per_partition_bounds(model, np)

# %%
model = "../trained_models/pinn-burgers-vis-1500.pt"
np = 150
visualize_per_partition_bounds_mult(model, np, ((-1, -0.1), (0.1, 1)), ((0, 1),(0, 1)))
